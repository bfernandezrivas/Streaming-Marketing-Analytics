# %%
import pandas as pd

input_file = "DATA/PROCESSED/all_streaming_titles_enriched.csv"
output_file = "DATA/PROCESSED/all_streaming_titles_clean_sql.csv"

df = pd.read_csv(input_file, encoding="utf-8-sig")

df.to_csv(output_file, index=False, encoding="utf-8")

print("CSV clean:", output_file)
# Out:
# CSV clean: DATA/PROCESSED/all_streaming_titles_clean_sql.csv

# %%
#!pip install sqlalchemy pymysql

# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv

load_dotenv()

DB_PASSWORD = os.environ.get("DB_PASSWORD", "")

# 1. reed csv
df = pd.read_csv("DATA/PROCESSED/all_streaming_titles_clean_sql.csv", encoding="utf-8")

# 2. clean for SQL
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

# 3. Connect to MySQL
engine = create_engine(
    f"mysql+pymysql://root:{DB_PASSWORD}@localhost:3306/streaming_marketing_analytics?charset=utf8mb4"
)

# 4. send to SQL
df.to_sql(
    "all_streaming_titles",
    con=engine,
    if_exists="replace",
    index=False
)

print("import to SQL completed")
# Out:
# import to SQL completed
